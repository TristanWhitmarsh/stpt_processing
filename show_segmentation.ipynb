# %%
file_names_all = [
('20190911_PDX_STG316_gfp_100x15um', 1, 50, 0, 150, 0, -45, 0.3, 6, 0, 40),
('20190916_PDX_STG316_gfp_100x15um_set2', 1, 100, 0, 200, 0, -45, 0.3, 6, 0, 0),
('20190919_PDX_STG139645_gfp_100x15um', 2, 200, 0, 0, 0, 150, 0.3, 2.5, 0, 40),
('20190923_PDX_STG139645_gfp_100x15um_set2', 2, 200, 0, 0, 0, -210, 0.3, 3, 0, 0),
('20191021_PDX_STG143_100x15um', 2, 300, 0, 0, 0, -155, 0.2, 1, 0, 40),
('20191028_PDX_STG143_100x15um_set2', 2, 300, 0, 0, 0, -150, 0.3, 1.2, 0, 0),
('20191209_PDX_STG143SC_50x15um', 1, 50, 0, 750, 0, 75, 0.2, 2.25, 0, 0),
('20191210_PDX_STG143SC_100x15um_set2', 1, 150, 0, 750, 0, 70, 0.2, 1, 0, 30),  
('20200219_PDX_AB559_50X15um', 0, 0, 0, 0, 0, 0, 0.3, 5.0, 0, 0),
('20200225_PDX_Ab559_set2_100X15um', 0, 0, 0, 0, 0, 0, 0.2, 5, 0, 20),
('20200226_PDX_Ab580_HC_gfp_100x15um', 1, 200, 0, 200, 0, -20, 0.3, 2, 0, 0),
('20200227_PDX_Ab580_HC_gfp_set2_100x15um', 1, 200, 0, 100, 0, -18, 0.2, 4, 0, 40),
('20200615_PDX_AB580_GFP_100x15um_set1', 1, 100, 0, 100, 0, 45,  0.1, 2, 30, 1),
('20200629_PDX_PAR1040_GFP_100x15um_set1', 2, 150, 0, 0, 0, -100,  0.1, 4, 0, 0),
('20200707_PDX_PAR1040_GFP_100x15um_set2', 2, 150, 0, 0, 0, -105,  0.2, 2.5, 0, 0),
('20200804_PDX_AB580SC_gfp_100x15um_set1', 1, 200, 0, 100, 0, -170, 0.1, 2.5, 0, 0),
('20200817_PDX_AB764_017376_gfp_100x15um_set1', 1, 400, 0, 200, 0, 60,  0.07, 4, 0, 0),
('20200818_PDX_PAR1006_gfp_100x15um_set1', 1, 100, 0, 100, 0, 123, 0.1, 1.7, 1, 10),
('20200902_PDX_PAR1059_gfp_100x15um_set1', 2, 100, 0, 0, 0, 30, 0.1, 2, 0, 30), 
('20200908_PDX_PAR1022_gfp_100x15um_set1', 2, 200, 0, 0, 0, -120, 0.1, 3, 0, 50),
('20201103_PDX_PAR1022_GFP_Rep2_100x15um', 1, 100, 0, 100, 0, -130, 0.1, 2.5, 0, 0),
('20201109_PDX_STG1394_GFP_100x15um', 1, 300, 0, 100, 0, -90, 0.25, 2, 1, 40),
('20201110_PDX_HC1010_GFP_100x15um', 2, 200, 0, 0, 0, -100, 0.1, 1.5, 0, 0),
('20201207_PDX_PAR1059x2GFP_100x15um', 1, 300, 0, 0, 0, 45, 0.1, 1.7, 50, 0),
('20201216_PDX_STG143_SC_GFP_100x15um', 1, 200, 0, 100, 0, -120, 0.2, 1.5, 0, 0),
('20210104_PDX_AB580Sc_GFP_100x15um', 1, 250, 0, 100, 0, -100, 0.1, 0.5, 0, 0),
('20210105_PDX_STG316_GFP_rep1_100x15um', 1, 200, 0, 200, 0, -105, 0.05, 0.4, 0, 30),
('20210111_PDX_STG143_2HC_GFP_100x15um', 2, 100, 0, 0, 0, -45, 0.05, 0.12, 27, 0),
('20210119_PDX_STG316_GFP_100x15um', 1, 200, 0, 600, 0, 40, 0.1, 1, 0, 0),
('20210121_PDX_STG316_GFP_001389_100x15um', 1, 500, 250, 300, 100, 90, 0.05, 0.65, 0, 0),
('20210126_AB764_017377_100x15um_gfp', 2, 150, 0, 0, 0, 115, 0.2, 2.5, 50, 0),
('20210127_PDX_AB630_GFP_100x15um', 2, 150, 0, 0, 0, -35, 0.1, 1.3, 0, 0),   
('20210211_PDX_PAR1006_GFP_100x15um', 1, 400, 250, 200, 0, -60, 0.05, 1.2, 70, 0),
('20210315_PDX_AB582P_GFP_100x15um', 1, 150, 0, 100, 0, -220, 0.3, 9, 0, 0),
('20210406_PDX_CAHBHT_GFP_100x15um', 2, 200, 0, 0, 0, -135, 0.3, 4, 0, 0),
('20210407_PDX_STG139_GFP_100x15um', 1, 200, 0, 200, 0, 130, 0.3, 4, 0, 0),
('20210409_PDX_CAHBHTI_GFP_100x15um_set2', 2, 100, 0, 0, 0, 135, 0.3, 7, 0, 0),
('20210706_PDX_STG139_GFP_029630_100x15um', 2, 100, 0, 0, 0, -145, 0.3, 6, 0, 0),
('20211103_PDX_STG139M_GFP_031776_100x15um', 1, 150, 0, 100, 0, -135, 0.3, 8, 0, 0),
('20211104_PDX_STG139_GFP_039629_100x15um', 2, 250, 0, 0, 0, -140, 0.3, 8, 40, 0),
('20211108_PDX_STG139M_GFP_029620_100x15um', 2, 400, 0, 0, 0, -120, 0.3, 8, 0, 40),
('20211109_PDX_STG139_GFP_029630_100x15um', 2, 150, 0, 0, 0, 65, 0.3, 7, 0, 45),
('20211115_PDX_STG139_031772_50x15um', 1, 100, 0, 100, 0, -35, 0.3, 6, 0, 0),
('20211129_PDX_STG139_GFP_039629_100x15um', 2, 100, 0, 0, 0, -60, 0.3, 5, 0, 0),
('20220106_PDX_PAR1040_GFP_019611_100x15um', 1, 100, 0, 100, 300, -130, 0.1, 2.5, 15, 0), 
('20220110_PDX_STG139_GFP_018314_100x15um', 1, 700, 0, 200, 150, 125, 0.1, 2.5, 20, 0),
('20220127_PDX_PAR1040_GFP_019612_100x15um', 1, 300, 0, 100, 0, 39, 0.1, 3.0, 0, 0),
('20220214_PDX_STG139_GFP_019465_100x15um', 1, 300, 0, 200, 0, -65, 0.1, 0.6, 0, 0),
('20220223_PDX_STG139_GFP_018308_100x15um', 1, 150, 0, 150, 0, 60, 0.1, 0.8, 0, 0),
('20220228_PDX_PAR1040_GFP_019610_100x15um', 1, 250, 0, 450, 0, -50, 0.3, 13, 0, 0),
('20220428_PDX_AB559_GFP_002213_100x15um', 1, 100, 0, 300, 0, -45, 0.1, 12.0, 0, 0),
('20220503_PDX_AB559_GFP_002215_100x15um', 1, 100, 200, 100, 0, 85, 0.1, 7.0, 0, 0),
('PDX_PAR1141_gfp_100x15um_set1', 1, 100, 0, 300, 0, 60, 0.1, 4.5, 0, 2),
('20210422_STG139_GFP_100x15um', 2, 200, 0, 0, 0, -150, 0.2, 7.0, 0, 0),
('20211020_PDX_STG139_GFP_029621_100x15um', 2, 150, 50, 0, 0, 120, 1, 15, 0, 0),
('20210324_PDX_STG139_GFP_100x15um', 1, 200, 0, 300, 0, -120, 50, 400, 0, 0),
]

# %%
from PyPDF2 import PdfMerger

import SimpleITK as sitk
from matplotlib import pyplot as plt 

import gc

merger = PdfMerger()
count = 1
for file_name, full_corner_half, cut_off_x_left, cut_off_x_right, cut_off_y_bottom, cut_off_y_top, angle, threshold_tissue, threshold_stroma, cut_off_bottom, cut_off_top in file_names_all:

    file_name = "../../Storage/segmentations/" + file_name + ".nii"
    
    print(file_name)
    
    volume_itk = sitk.ReadImage(file_name)
    volume = sitk.GetArrayFromImage(volume_itk)
    
    plt.rcParams["figure.figsize"] = (10, 10)
    plt.imshow(volume[int(volume.shape[0]/2)], interpolation='nearest', cmap=plt.get_cmap("nipy_spectral"), vmin=0, vmax=19)
    plt.title(file_name)
    #plt.show()
    
    plt.savefig('image'+str(count)+'.pdf', bbox_inches = 'tight')
    merger.append('image'+str(count)+'.pdf')
    count = count + 1
    
    del volume_itk
    del volume
    gc.collect()
    
merger.write("images.pdf")
merger.close()
# Out:
# ../../Storage/segmentations/20190911_PDX_STG316_gfp_100x15um.nii
# ../../Storage/segmentations/20190916_PDX_STG316_gfp_100x15um_set2.nii
# ../../Storage/segmentations/20190919_PDX_STG139645_gfp_100x15um.nii
# ../../Storage/segmentations/20190923_PDX_STG139645_gfp_100x15um_set2.nii
# ../../Storage/segmentations/20191021_PDX_STG143_100x15um.nii
# ../../Storage/segmentations/20191028_PDX_STG143_100x15um_set2.nii
# ../../Storage/segmentations/20191209_PDX_STG143SC_50x15um.nii
# ../../Storage/segmentations/20191210_PDX_STG143SC_100x15um_set2.nii
# ../../Storage/segmentations/20200219_PDX_AB559_50X15um.nii
# ../../Storage/segmentations/20200225_PDX_Ab559_set2_100X15um.nii
# ../../Storage/segmentations/20200226_PDX_Ab580_HC_gfp_100x15um.nii
# ../../Storage/segmentations/20200227_PDX_Ab580_HC_gfp_set2_100x15um.nii
# ../../Storage/segmentations/20200615_PDX_AB580_GFP_100x15um_set1.nii
# ../../Storage/segmentations/20200629_PDX_PAR1040_GFP_100x15um_set1.nii
# ../../Storage/segmentations/20200707_PDX_PAR1040_GFP_100x15um_set2.nii
# ../../Storage/segmentations/20200804_PDX_AB580SC_gfp_100x15um_set1.nii
# ../../Storage/segmentations/20200817_PDX_AB764_017376_gfp_100x15um_set1.nii
# ../../Storage/segmentations/20200818_PDX_PAR1006_gfp_100x15um_set1.nii
# ../../Storage/segmentations/20200902_PDX_PAR1059_gfp_100x15um_set1.nii
# ../../Storage/segmentations/20200908_PDX_PAR1022_gfp_100x15um_set1.nii
# ../../Storage/segmentations/20201103_PDX_PAR1022_GFP_Rep2_100x15um.nii
# ../../Storage/segmentations/20201109_PDX_STG1394_GFP_100x15um.nii
# ../../Storage/segmentations/20201110_PDX_HC1010_GFP_100x15um.nii
# ../../Storage/segmentations/20201207_PDX_PAR1059x2GFP_100x15um.nii
# ../../Storage/segmentations/20201216_PDX_STG143_SC_GFP_100x15um.nii
# ../../Storage/segmentations/20210104_PDX_AB580Sc_GFP_100x15um.nii
# ../../Storage/segmentations/20210105_PDX_STG316_GFP_rep1_100x15um.nii
# ../../Storage/segmentations/20210111_PDX_STG143_2HC_GFP_100x15um.nii
# ../../Storage/segmentations/20210119_PDX_STG316_GFP_100x15um.nii
# ../../Storage/segmentations/20210121_PDX_STG316_GFP_001389_100x15um.nii
# ../../Storage/segmentations/20210126_AB764_017377_100x15um_gfp.nii
# ../../Storage/segmentations/20210127_PDX_AB630_GFP_100x15um.nii
# ../../Storage/segmentations/20210211_PDX_PAR1006_GFP_100x15um.nii
# ../../Storage/segmentations/20210315_PDX_AB582P_GFP_100x15um.nii
# ../../Storage/segmentations/20210406_PDX_CAHBHT_GFP_100x15um.nii
# ../../Storage/segmentations/20210407_PDX_STG139_GFP_100x15um.nii
# ../../Storage/segmentations/20210409_PDX_CAHBHTI_GFP_100x15um_set2.nii
# ../../Storage/segmentations/20210706_PDX_STG139_GFP_029630_100x15um.nii
# ../../Storage/segmentations/20211103_PDX_STG139M_GFP_031776_100x15um.nii
# ../../Storage/segmentations/20211104_PDX_STG139_GFP_039629_100x15um.nii
# ../../Storage/segmentations/20211108_PDX_STG139M_GFP_029620_100x15um.nii
# ../../Storage/segmentations/20211109_PDX_STG139_GFP_029630_100x15um.nii
# ../../Storage/segmentations/20211115_PDX_STG139_031772_50x15um.nii
# ../../Storage/segmentations/20211129_PDX_STG139_GFP_039629_100x15um.nii
# ../../Storage/segmentations/20220106_PDX_PAR1040_GFP_019611_100x15um.nii
# ../../Storage/segmentations/20220110_PDX_STG139_GFP_018314_100x15um.nii
# ../../Storage/segmentations/20220127_PDX_PAR1040_GFP_019612_100x15um.nii
# ../../Storage/segmentations/20220214_PDX_STG139_GFP_019465_100x15um.nii
# ../../Storage/segmentations/20220223_PDX_STG139_GFP_018308_100x15um.nii
# ../../Storage/segmentations/20220228_PDX_PAR1040_GFP_019610_100x15um.nii
# ../../Storage/segmentations/20220428_PDX_AB559_GFP_002213_100x15um.nii
# ../../Storage/segmentations/20220503_PDX_AB559_GFP_002215_100x15um.nii
# ../../Storage/segmentations/PDX_PAR1141_gfp_100x15um_set1.nii
# ../../Storage/segmentations/20210422_STG139_GFP_100x15um.nii
# ../../Storage/segmentations/20211020_PDX_STG139_GFP_029621_100x15um.nii
# ../../Storage/segmentations/20210324_PDX_STG139_GFP_100x15um.nii
